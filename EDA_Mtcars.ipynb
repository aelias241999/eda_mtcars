# %% [markdown]
# <a href="https://colab.research.google.com/github/aelias241999/eda_mtcars/blob/main/EDA_Mtcars.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Análisis
# ######Librerías

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ####Carga de Datos

# %%
#Importar dataset Mtcars
data=!wget https://raw.githubusercontent.com/selva86/datasets/master/mtcars.csv #traemos dataset para trabajar

#Carga de datos
df=pd.read_csv("mtcars.csv")
df_work=df.copy()
df_work.round(2) #mostramos dataset con valores redondeados a 2 decimales
df_work.head(7) #primeros 7 valores del dataset
# Out:
#         mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb  fast  \
# 0  4.582576    6  160.0  110  3.90  2.620  16.46   0   1     4     4     1
# 1  4.582576    6  160.0  110  3.90  2.875  17.02   0   1     4     4     1
# 2  4.774935    4  108.0   93  3.85  2.320  18.61   1   1     4     1     1
# 3  4.626013    6  258.0  110  3.08  3.215  19.44   1   0     3     1     1
# 4  4.324350    8  360.0  175  3.15  3.440  17.02   0   0     3     2     1
# 5  4.254409    6  225.0  105  2.76  3.460  20.22   1   0     3     1     1
# 6  3.781534    8  360.0  245  3.21  3.570  15.84   0   0     3     4     0
#
#                 cars            carname
# 0          Mazda RX4          Mazda RX4
# 1      Mazda RX4 Wag      Mazda RX4 Wag
# 2         Datsun 710         Datsun 710
# 3     Hornet 4 Drive     Hornet 4 Drive
# 4  Hornet Sportabout  Hornet Sportabout
# 5            Valiant            Valiant
# 6         Duster 360         Duster 360

# %% [markdown]
# ####Limpieza de datos

# %%
df_work.isnull().sum()
#eliminar duplicados(si los hay)

print("Ducplicados antes:", df_work.duplicated().sum())
#df_work=df_work.drop_duplicates()
print("Duplicados después:",df_work.duplicated().sum())

#Nulos (si los hay)
print("Nulos:")
print(df_work.isnull().sum())

#Eliminar (innecesario ya que no hay nulos)
#df_work=df_work.dropna()

df_work.dtypes
# Out:
# Ducplicados antes: 0
# Duplicados después: 0
# Nulos:
# mpg        0
# cyl        0
# disp       0
# hp         0
# drat       0
# wt         0
# qsec       0
# vs         0
# am         0
# gear       0
# carb       0
# fast       0
# cars       0
# carname    0
# dtype: int64
# mpg        float64
# cyl          int64
# disp       float64
# hp           int64
# drat       float64
# wt         float64
# qsec       float64
# vs           int64
# am           int64
# gear         int64
# carb         int64
# fast         int64
# cars        object
# carname     object
# dtype: object

# %%
df_work.info() #dimensiones del dataset
          #tipos de datos
          #vista general de columnas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   mpg      32 non-null     float64
#  1   cyl      32 non-null     int64
#  2   disp     32 non-null     float64
#  3   hp       32 non-null     int64
#  4   drat     32 non-null     float64
#  5   wt       32 non-null     float64
#  6   qsec     32 non-null     float64
#  7   vs       32 non-null     int64
#  8   am       32 non-null     int64
#  9   gear     32 non-null     int64
#  10  carb     32 non-null     int64
#  11  fast     32 non-null     int64
#  12  cars     32 non-null     object
#  13  carname  32 non-null     object
# dtypes: float64(5), int64(7), object(2)
# memory usage: 3.6+ KB

# %% [markdown]
# ####Análisis Exploratorio (EDA)

# %%
df_work.describe().round()
# Out:
#         mpg   cyl   disp     hp  drat    wt  qsec    vs    am  gear  carb  \
# count  32.0  32.0   32.0   32.0  32.0  32.0  32.0  32.0  32.0  32.0  32.0
# mean    4.0   6.0  231.0  147.0   4.0   3.0  18.0   0.0   0.0   4.0   3.0
# std     1.0   2.0  124.0   69.0   1.0   1.0   2.0   1.0   0.0   1.0   2.0
# min     3.0   4.0   71.0   52.0   3.0   2.0  14.0   0.0   0.0   3.0   1.0
# 25%     4.0   4.0  121.0   96.0   3.0   3.0  17.0   0.0   0.0   3.0   2.0
# 50%     4.0   6.0  196.0  123.0   4.0   3.0  18.0   0.0   0.0   4.0   2.0
# 75%     5.0   8.0  326.0  180.0   4.0   4.0  19.0   1.0   1.0   4.0   4.0
# max     6.0   8.0  472.0  335.0   5.0   5.0  23.0   1.0   1.0   5.0   8.0
#
#        fast
# count  32.0
# mean    1.0
# std     0.0
# min     0.0
# 25%     0.0
# 50%     1.0
# 75%     1.0
# max     1.0

# %%
df_work.shape #filas & columnas
# Out:
# (32, 14)

# %% [markdown]
# ####Calidad de Datos
# ####Outliers

# %%
sns.histplot(df["mpg"], kde=True)
# Out:
# <Axes: xlabel='mpg', ylabel='Count'>

# %% [markdown]
# ####Análisis y Visualización
#
# ###¿Autos pesados consumen más?

# %%
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

plt.scatter(df_work["wt"], df_work["mpg"])
plt.xlabel("Weight")
plt.ylabel("MPG")
plt.title("Weigth vs MPG")
plt.show()

#Interactivo
fig=px.scatter(
    df_work,
    x="wt",
    y="mpg",
    color_discrete_sequence=["brown"]
)
fig.update_layout(
    plot_bgcolor="black", #fondo gráfico
    paper_bgcolor="black", #fondo exterior
    font=dict(color="white") #texto blanco
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ####Conclusión Final

# %%
#Reporte
# !pip install ydata-profiling
from ydata_profiling import ProfileReport

profile=ProfileReport(df_work, title="Exploration Data Analysis", explorative=True)
profile.to_file("EDA_Report.html")

#import webbrowser
#webbrowser.open("EDA_Report.html")
